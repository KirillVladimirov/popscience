# %%
from pytube import YouTube
from pytube import Playlist
# misc
import os
import shutil
import math
import datetime
# plots
import matplotlib.pyplot as plt
# %matplotlib inline
# image operation
import cv2

import pprint
from tqdm.notebook import tqdm

import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
with open('youtube_links_list.txt') as f:
    youtube_links_list = f.read().splitlines()
# Out:
# /home/science/university2035_projects/workspace/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(youtube_links_list)
# Out:
# 136695

# %%
youtube_links_list = list(set(youtube_links_list))
len(youtube_links_list)
# Out:
# 105294

# %%
hash(youtube_links_list[0])
# Out:
# -4615810308234543104

# %%
youtube_info = {}

# %%
with open('youtube_info.pickle', 'rb') as f:
    youtube_info = pickle.load(f)

# %%
for url in tqdm(youtube_links_list):
    if hash(url) not in youtube_info:
        info = {}
        yt = YouTube(url)
        info["title"] = yt.title
        info["date"] = yt.publish_date
        info["origin_url"] = url
        info["views"] = yt.views
        info["duation"] = yt.length
        info["author"] = yt.author
        info["tags"] = yt.keywords
        info["about"] = yt.description
        info["rating"] = yt.rating
        info["platform"] = "YouTube"
        info["theme"] = yt.thumbnail_url
        if yt.captions.get("ru") is not None:
            caption = yt.captions.get_by_language_code('ru')
            info["language"] = "ru"
        elif yt.captions.get("a.ru") is not None:
            caption = yt.captions.get_by_language_code('a.ru')
            info["language"] = "a.ru"
        if caption:
            info["captions_xml"] = caption.xml_captions
            info["captions_str"] = caption.generate_srt_captions()
        youtube_info[hash(url)] = info
# Out:
#   0%|          | 0/105294 [00:00<?, ?it/s]
# <ipython-input-44-eca1f42ea0a8>:20: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('a.ru')
# <ipython-input-44-eca1f42ea0a8>:20: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('a.ru')
# <ipython-input-44-eca1f42ea0a8>:17: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('ru')
# <ipython-input-44-eca1f42ea0a8>:20: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('a.ru')
# ...

# %%
with open('youtube_info.pickle', 'wb') as f:
    pickle.dump(youtube_info, f)
# Out:
# /home/science/university2035_projects/workspace/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(youtube_info)
# Out:
# 7217

# %%
youtube_info[hash(youtube_links_list[79])]
# Out:
# {'title': 'GMAT: Математика, часть 39',
#  'date': datetime.datetime(2014, 9, 29, 0, 0),
#  'origin_url': 'https://www.youtube.com/watch?v=GXyPAPZppQ4',
#  'views': 114,
#  'duation': 717,
#  'author': 'KhanAcademyRussian',
#  'tags': [],
#  'about': 'GMAT: Math 39',
#  'rating': 0.0,
#  'platform': 'YouTube',
#  'theme': 'https://i.ytimg.com/vi/GXyPAPZppQ4/hqdefault.jpg?sqp=-oaymwEjCNACELwBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC6frJBOoImph1Hrvhchbg-2CgD4A',
#  'language': 'ru',
# ...

# %%
caption.xml_captions
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><transcript><text start="0.439" dur="11.991">вот сайт с шаурмой works</text><text start="4.1" dur="8.33">[музыка]</text><text start="13.79" dur="4.329">что такое свет</text><text start="15.36" dur="7.11">что такое свет свет это что есть цвет</text><text start="18.119" dur="7.89">хороший вопрос что такое свет это</text><text start="22.47" dur="7.039">элемент свет это яркость наверное у нас</text><text start="26.009" dur="6.631">есть ауры да уж снова и света да верно</text><text start="29.509" dur="5.311">делает комната светлый но не темный</text><text start="32.64" dur="5.13">синий цвет и красный чем разница в цвете</text><text start="34.82" dur="5.98">он попадает в глаза и ты видишь по</text><text start="37.77" dur="6.09">порядку белый красный оранжевый зеленый</text><text start="40.8" dur="7.05">как чакры нашего тела вы видите мою ауру</text><text start="43.86" dur="6.3">прямо сейчас нет слишком светло до</text><text start="47.85" dur="4.19">с
# ...
